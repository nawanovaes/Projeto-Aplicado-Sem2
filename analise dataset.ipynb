# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importando data

# %%
data = pd.read_csv('owid-energy-data.csv')

# %%
data.describe()
# Out:
#                year    population           gdp  biofuel_cons_change_pct  \
# count  22012.000000  1.812300e+04  1.111300e+04              1747.000000
# mean    1974.213247  1.053096e+08  3.585114e+11                46.091694
# std       35.058653  4.640460e+08  2.411179e+12               274.616745
# min     1900.000000  1.833000e+03  1.642060e+08              -100.000000
# 25%     1946.000000  1.712404e+06  1.365898e+10                -0.616500
# 50%     1984.000000  6.991543e+06  4.167411e+10                 8.179000
# 75%     2003.000000  2.557688e+07  1.744295e+11                26.508500
# max     2022.000000  7.975105e+09  1.136302e+14              5659.328000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# count              2687.000000              2302.000000          2767.000000
# mean                  2.719074               133.558459            38.068209
# std                  10.057018               264.707851           111.623148
# ...

# %% [markdown]
# # Criando coluna fonte

# %%
data[data['country'].str.contains('\(')].country.unique()
# Out:
# array(['ASEAN (Ember)', 'Africa (EI)', 'Africa (Ember)', 'Africa (Shift)',
#        'Asia & Oceania (EIA)', 'Asia (Ember)', 'Asia Pacific (EI)',
#        'Asia and Oceania (Shift)', 'Australia and New Zealand (EIA)',
#        'CIS (EI)', 'Central & South America (EIA)',
#        'Central America (EI)', 'Central and South America (Shift)',
#        'EU28 (Shift)', 'East Germany (EIA)', 'Eastern Africa (EI)',
#        'Eurasia (EIA)', 'Eurasia (Shift)', 'Europe (EI)',
#        'Europe (Ember)', 'Europe (Shift)', 'European Union (27)',
#        'European Union (EIA)', 'G20 (Ember)', 'G7 (Ember)',
#        'Hawaiian Trade Zone (EIA)', 'IEO - Africa (EIA)',
#        'IEO - Middle East (EIA)', 'IEO OECD - Europe (EIA)',
#        'Latin America and Caribbean (Ember)',
#        'Mexico, Chile, and other OECD Americas (EIA)',
#        'Micronesia (country)', 'Middle Africa (EI)', 'Middle East (EI)',
#        'Middle East (EIA)', 'Middle East (Ember)', 'Middle East (Shift)',
# ...

# %%
data.insert(1, 'fonte', '')

# %%
data['fonte'] = data['country'].str.extract('.*\((.*)\).*')

# %%
data.head()
# Out:
#          country  fonte  year iso_code  population  gdp  \
# 0  ASEAN (Ember)  Ember  2000      NaN         NaN  NaN
# 1  ASEAN (Ember)  Ember  2001      NaN         NaN  NaN
# 2  ASEAN (Ember)  Ember  2002      NaN         NaN  NaN
# 3  ASEAN (Ember)  Ember  2003      NaN         NaN  NaN
# 4  ASEAN (Ember)  Ember  2004      NaN         NaN  NaN
#
#    biofuel_cons_change_pct  biofuel_cons_change_twh  biofuel_cons_per_capita  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    biofuel_consumption  ...  solar_share_elec  solar_share_energy  \
# 0                  NaN  ...               0.0                 NaN
# ...

# %% [markdown]
# # Criando coluna sem fonte

# %%
data.insert(1, 'country2', data['country'])
data
# Out:
#              country       country2  fonte  year iso_code  population  \
# 0      ASEAN (Ember)  ASEAN (Ember)  Ember  2000      NaN         NaN
# 1      ASEAN (Ember)  ASEAN (Ember)  Ember  2001      NaN         NaN
# 2      ASEAN (Ember)  ASEAN (Ember)  Ember  2002      NaN         NaN
# 3      ASEAN (Ember)  ASEAN (Ember)  Ember  2003      NaN         NaN
# 4      ASEAN (Ember)  ASEAN (Ember)  Ember  2004      NaN         NaN
# ...              ...            ...    ...   ...      ...         ...
# 22007       Zimbabwe       Zimbabwe    NaN  2018      ZWE  15052191.0
# 22008       Zimbabwe       Zimbabwe    NaN  2019      ZWE  15354606.0
# 22009       Zimbabwe       Zimbabwe    NaN  2020      ZWE  15669663.0
# 22010       Zimbabwe       Zimbabwe    NaN  2021      ZWE  15993525.0
# 22011       Zimbabwe       Zimbabwe    NaN  2022      ZWE  16320539.0
#
#                 gdp  biofuel_cons_change_pct  biofuel_cons_change_twh  \
# ...

# %%
data['country2'] = data['country'].str.replace(r"\(.*\)", '').str.strip()
# Out:
# C:\Users\nawan\AppData\Local\Temp\ipykernel_10632\3993442352.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['country2'] = data['country'].str.replace(r"\(.*\)", '').str.strip()

# %%
data[data['country2'].str.contains('Europe')].country2.unique()
# Out:
# array(['Europe', 'European Union', 'IEO OECD - Europe', 'OECD - Europe',
#        'Other Non-OECD - Europe and Eurasia'], dtype=object)

# %% [markdown]
# # Criando df por fonte

# %%
fonte = pd.DataFrame(data.fonte.unique(), columns = ['fonte'])
fonte = fonte.fillna('-')
data['fonte'] = data['fonte'].fillna('-')

# %%
fonte = list(fonte['fonte'])
fonte
# Out:
# ['Ember', '-', 'EI', 'Shift', 'EIA', '27', 'country']

# %%
dfs = list(range(7))

# %%
for i in range(len(fonte)):
    dfs[i] = pd.DataFrame(data = data[data['fonte'] == fonte[i]].replace(0, np.nan).dropna(axis = 1, how = 'all'))

# %%
fonte
# Out:
# ['Ember', '-', 'EI', 'Shift', 'EIA', '27', 'country']

# %%
ember = dfs[0]
paises = dfs[1]
ei = dfs[2]
shift = dfs[3]
eia = dfs[4]
vintesete = dfs[5]
country = dfs[6]

# %%
paises.to_csv('paises.csv')

# %%
paises.describe()
# Out:
#                year    population           gdp  biofuel_cons_change_pct  \
# count  18166.000000  1.795800e+04  1.111300e+04              1396.000000
# mean    1972.159584  1.038116e+08  3.585114e+11                52.746303
# std       35.595559  4.656392e+08  2.411179e+12               305.208669
# min     1900.000000  1.833000e+03  1.642060e+08              -100.000000
# 25%     1942.000000  1.713595e+06  1.365898e+10                -1.205500
# 50%     1982.000000  6.926826e+06  4.167411e+10                 8.023000
# 75%     2002.000000  2.484284e+07  1.744295e+11                27.319250
# max     2022.000000  7.975105e+09  1.136302e+14              5659.328000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# count              1431.000000              1473.000000          1471.000000
# mean                  3.307607               204.742842            46.301710
# std                  11.322195               306.813785           126.944898
# ...

# %%
paises[paises['country'] == 'Brazil']
# Out:
#      country country2 fonte  year iso_code   population           gdp  \
# 2853  Brazil   Brazil     -  1900      BRA   18058538.0  1.571802e+10
# 2854  Brazil   Brazil     -  1901      BRA   18463951.0  1.728848e+10
# 2855  Brazil   Brazil     -  1902      BRA   18869255.0  1.729822e+10
# 2856  Brazil   Brazil     -  1903      BRA   19274237.0  1.764560e+10
# 2857  Brazil   Brazil     -  1904      BRA   19687910.0  1.798087e+10
# ...      ...      ...   ...   ...      ...          ...           ...
# 2971  Brazil   Brazil     -  2018      BRA  210166592.0  2.965402e+12
# 2972  Brazil   Brazil     -  2019      BRA  211782880.0           NaN
# 2973  Brazil   Brazil     -  2020      BRA  213196304.0           NaN
# 2974  Brazil   Brazil     -  2021      BRA  214326224.0           NaN
# 2975  Brazil   Brazil     -  2022      BRA  215313504.0           NaN
#
#       biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 2853                      NaN                      NaN
# ...

# %%
fonte
# Out:
# ['Ember', '-', 'EI', 'Shift', 'EIA', '27', 'country']

# %%
eia.country.unique()
# Out:
# array(['Asia & Oceania (EIA)', 'Australia and New Zealand (EIA)',
#        'Central & South America (EIA)', 'East Germany (EIA)',
#        'Eurasia (EIA)', 'European Union (EIA)',
#        'Hawaiian Trade Zone (EIA)', 'IEO - Africa (EIA)',
#        'IEO - Middle East (EIA)', 'IEO OECD - Europe (EIA)',
#        'Mexico, Chile, and other OECD Americas (EIA)',
#        'Middle East (EIA)', 'Non-OECD (EIA)', 'Non-OPEC (EIA)',
#        'OECD (EIA)', 'OECD - Asia And Oceania (EIA)',
#        'OECD - Europe (EIA)', 'OECD - North America (EIA)', 'OPEC (EIA)',
#        'OPEC - Africa (EIA)', 'OPEC - South America (EIA)',
#        'Other Non-OECD - America (EIA)', 'Other Non-OECD - Asia (EIA)',
#        'Other Non-OECD - Europe and Eurasia (EIA)', 'Persian Gulf (EIA)',
#        'South Korea and other OECD Asia (EIA)',
#        'U.S. Pacific Islands (EIA)', 'U.S. Territories (EIA)',
#        'Wake Island (EIA)', 'West Germany (EIA)'], dtype=object)

# %%
vintesete.country.unique()
# Out:
# array(['European Union (27)'], dtype=object)

# %%
shift.country.unique()
# Out:
# array(['Africa (Shift)', 'Asia and Oceania (Shift)',
#        'Central and South America (Shift)', 'EU28 (Shift)',
#        'Eurasia (Shift)', 'Europe (Shift)', 'Middle East (Shift)',
#        'North America (Shift)', 'OECD (Shift)', 'OPEC (Shift)',
#        'Persian Gulf (Shift)', 'United States Pacific Islands (Shift)',
#        'United States Territories (Shift)', 'Wake Island (Shift)'],
#       dtype=object)

# %%
ember.country.unique()
# Out:
# array(['ASEAN (Ember)', 'Africa (Ember)', 'Asia (Ember)',
#        'Europe (Ember)', 'G20 (Ember)', 'G7 (Ember)',
#        'Latin America and Caribbean (Ember)', 'Middle East (Ember)',
#        'North America (Ember)', 'OECD (Ember)', 'Oceania (Ember)'],
#       dtype=object)

# %%
ei.country.unique()
# Out:
# array(['Africa (EI)', 'Asia Pacific (EI)', 'CIS (EI)',
#        'Central America (EI)', 'Eastern Africa (EI)', 'Europe (EI)',
#        'Middle Africa (EI)', 'Middle East (EI)', 'Non-OECD (EI)',
#        'Non-OPEC (EI)', 'North America (EI)', 'OECD (EI)', 'OPEC (EI)',
#        'South and Central America (EI)', 'Western Africa (EI)'],
#       dtype=object)

# %%
paises.country.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Angola', 'Antarctica', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Cyprus',
#        'Czechia', 'Czechoslovakia', 'Democratic Republic of Congo',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic',
#        'East Timor', 'Ecuador', 'Egypt', 'El Salvador',
# ...

# %%
eia[eia['country2'] == 'European Union']
# Out:
#                    country        country2 fonte  year  \
# 7006  European Union (EIA)  European Union   EIA  1980
# 7007  European Union (EIA)  European Union   EIA  1981
# 7008  European Union (EIA)  European Union   EIA  1982
# 7009  European Union (EIA)  European Union   EIA  1983
# 7010  European Union (EIA)  European Union   EIA  1984
# 7011  European Union (EIA)  European Union   EIA  1985
# 7012  European Union (EIA)  European Union   EIA  1986
# 7013  European Union (EIA)  European Union   EIA  1987
# 7014  European Union (EIA)  European Union   EIA  1988
# 7015  European Union (EIA)  European Union   EIA  1989
# 7016  European Union (EIA)  European Union   EIA  1990
# 7017  European Union (EIA)  European Union   EIA  1991
# 7018  European Union (EIA)  European Union   EIA  1992
# 7019  European Union (EIA)  European Union   EIA  1993
# 7020  European Union (EIA)  European Union   EIA  1994
# 7021  European Union (EIA)  European Union   EIA  1995
# ...

# %%
vintesete2 = vintesete[['country', 'country2', 'fonte', 'year', 'energy_cons_change_pct', 'energy_cons_change_twh', 'primary_energy_consumption']]
vintesete2
# Out:
#                   country        country2 fonte  year  energy_cons_change_pct  \
# 6883  European Union (27)  European Union    27  1900                     NaN
# 6884  European Union (27)  European Union    27  1901                     NaN
# 6885  European Union (27)  European Union    27  1902                     NaN
# 6886  European Union (27)  European Union    27  1903                     NaN
# 6887  European Union (27)  European Union    27  1904                     NaN
# ...                   ...             ...   ...   ...                     ...
# 7001  European Union (27)  European Union    27  2018                  -0.100
# 7002  European Union (27)  European Union    27  2019                  -1.630
# 7003  European Union (27)  European Union    27  2020                  -7.450
# 7004  European Union (27)  European Union    27  2021                   5.294
# 7005  European Union (27)  European Union    27  2022                  -3.484
#
# ...

# %%
join = vintesete2.merge(eia[eia['country2'] == 'European Union'], how = 'inner', on = 'year')

# %%
join
# Out:
#               country_x      country2_x fonte_x  year  \
# 0   European Union (27)  European Union      27  1980
# 1   European Union (27)  European Union      27  1981
# 2   European Union (27)  European Union      27  1982
# 3   European Union (27)  European Union      27  1983
# 4   European Union (27)  European Union      27  1984
# 5   European Union (27)  European Union      27  1985
# 6   European Union (27)  European Union      27  1986
# 7   European Union (27)  European Union      27  1987
# 8   European Union (27)  European Union      27  1988
# 9   European Union (27)  European Union      27  1989
# 10  European Union (27)  European Union      27  1990
# 11  European Union (27)  European Union      27  1991
# 12  European Union (27)  European Union      27  1992
# 13  European Union (27)  European Union      27  1993
# 14  European Union (27)  European Union      27  1994
# 15  European Union (27)  European Union      27  1995
# ...
